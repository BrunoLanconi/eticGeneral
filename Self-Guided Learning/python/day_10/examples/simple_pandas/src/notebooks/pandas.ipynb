# %%
import pandas as pd # type: ignore

# %%
df = pd.read_csv("../../inputs/employees.csv")

# %%
df.head()
# Out:
#     Name  Age  Gender Department  Salary              Email       Phone  \
# 0  BONEA   21    Male    Finance   42202  bonea@company.com  1123722130
# 1  XQHON   43    Male         IT   74236  xqhon@company.com  6130078800
# 2  UTOAK   59    Male         IT   78578  utoak@company.com  3319202050
# 3  XIRCF   53  Female      Sales   37798  xircf@company.com  6920885000
# 4  IPMTO   32    Male      Sales   59528  ipmto@company.com   713293016
#
#       Address      City State Country  Postal Code
# 0  O6MDLUU0KD     Paris    NY   Japan        37621
# 1  Z22BPNPWCP  New York    TX  France        79289
# 2  WDA7VNA8WE    London    FL   Japan        52638
# 3  MW7GLE53MS  New York    CA     USA        50852
# 4  0Y8NYF4D7X  New York    NY     USA        71638

# %%
df.head(10)
# Out:
#     Name  Age  Gender Department  Salary              Email       Phone  \
# 0  BONEA   21    Male    Finance   42202  bonea@company.com  1123722130
# 1  XQHON   43    Male         IT   74236  xqhon@company.com  6130078800
# 2  UTOAK   59    Male         IT   78578  utoak@company.com  3319202050
# 3  XIRCF   53  Female      Sales   37798  xircf@company.com  6920885000
# 4  IPMTO   32    Male      Sales   59528  ipmto@company.com   713293016
# 5  LKISN   26  Female         IT   57274  lkisn@company.com  5623177397
# 6  ASPAN   48    Male    Finance   43958  aspan@company.com  5951480793
# 7  IPZVD   30  Female         IT   49956  ipzvd@company.com  9191954911
# 8  ERZND   35    Male  Marketing   38507  erznd@company.com  7459185183
# 9  LHBBV   52  Female         IT   50988  lhbbv@company.com  7131870916
#
#       Address      City State Country  Postal Code
# 0  O6MDLUU0KD     Paris    NY   Japan        37621
# 1  Z22BPNPWCP  New York    TX  France        79289
# ...

# %%
df.tail(5)
# Out:
#      Name  Age  Gender Department  Salary              Email       Phone  \
# 7   IPZVD   30  Female         IT   49956  ipzvd@company.com  9191954911
# 8   ERZND   35    Male  Marketing   38507  erznd@company.com  7459185183
# 9   LHBBV   52  Female         IT   50988  lhbbv@company.com  7131870916
# 10  ABGMK   21  Female         IT   76011  abgmk@company.com  2173055509
# 11  PUGBN   21    Male         IT   40193  pugbn@company.com  1775282046
#
#        Address      City State Country  Postal Code
# 7   89DWQS08LH  New York    NY     USA          249
# 8   YNB9M4CHXR    London    NY   Japan         5298
# 9   F1YEXKSOVP  New York    FL  France        26599
# 10  YJYH959VP1     Tokyo    TX   Japan        74696
# 11  VLQZEYEISD  New York    FL     USA        63674

# %%
df.shape
# Out:
# (12, 12)

# %%
df.size
# Out:
# 144

# %%
len(df)
# Out:
# 12

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Department', 'Salary', 'Email', 'Phone',
#        'Address', 'City', 'State', 'Country', 'Postal Code'],
#       dtype='object')

# %%
df["Age"]
# Out:
# 0     21
# 1     43
# 2     59
# 3     53
# 4     32
# 5     26
# 6     48
# 7     30
# 8     35
# 9     52
# 10    21
# 11    21
# Name: Age, dtype: int64

# %%
df[["Name", "Age"]]
# Out:
#      Name  Age
# 0   BONEA   21
# 1   XQHON   43
# 2   UTOAK   59
# 3   XIRCF   53
# 4   IPMTO   32
# 5   LKISN   26
# 6   ASPAN   48
# 7   IPZVD   30
# 8   ERZND   35
# 9   LHBBV   52
# 10  ABGMK   21
# 11  PUGBN   21

# %%
name_age_city_df = df[["Name", "Age", "City"]]

name_age_city_df.sort_values(by=["Age"]) # type: ignore
# Out:
#      Name  Age      City
# 0   BONEA   21     Paris
# 11  PUGBN   21  New York
# 10  ABGMK   21     Tokyo
# 5   LKISN   26    London
# 7   IPZVD   30  New York
# 4   IPMTO   32  New York
# 8   ERZND   35    London
# 1   XQHON   43  New York
# 6   ASPAN   48  New York
# 9   LHBBV   52  New York
# 3   XIRCF   53  New York
# 2   UTOAK   59    London

# %%
city_counts = name_age_city_df["City"].value_counts()

city_counts.plot(kind="bar")
# Out:
# <Axes: xlabel='City'>
